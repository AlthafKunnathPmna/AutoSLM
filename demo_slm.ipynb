# %%
from transformers import AutoTokenizer, AutoModelForCausalLM,AutoModelForSeq2SeqLM
import torch

model_path = "./student_model_instruct_openai-t5small"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSeq2SeqLM.from_pretrained(
    model_path,
    torch_dtype=torch.float16,
    device_map="auto"
)

prompt = "Give three tips for staying healthy."

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

output = model.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7
)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# Healthy diets are essential for maintaining healthy weight. They include: Keeping healthy, reducing stress, and reducing stress.

# %%
prompt = "How did Julius Caesar die?"

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

output = model.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7
)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# Julius Caesar died in a hospital in Rome, where he was buried.

# %%
prompt = "summerize the following Python is a popular high-level programming language known for its simple syntax and readability, which makes it easy for beginners to learn and powerful for professionals to use. Created by Guido van Rossum and first released in 1991, Python supports multiple programming styles, including procedural, object-oriented, and functional programming. It is widely used in many fields such as web development, data analysis, artificial intelligence, automation, and scientific computing. Frameworks and tools like Django, Flask, and libraries such as TensorFlow and NumPy make Python extremely versatile. Because of its large community, extensive libraries, and cross-platform compatibility, Python has become one of the most widely used programming languages in the world."

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

output = model.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7
)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# Python is a popular high-level programming language known for its simple syntax and readability, which makes it easy for beginners to learn and powerful for professionals to use. Created by Guido van Rossum and first released in 1991, Python supports multiple programming styles, including procedural, object-oriented, and functional programming. It is widely used in many fields such as web development, data analysis, artificial intelligence, automation, and scientific computing. Frameworks and tools like Django, Flask, and libraries such as TensorFlow and NumPy make Python extremely versatile. Because of its large community, extensive libraries, and cross-platform compatibility, Python has become one of the most widely used programming languages in the world.

# %%
model2_path = "./student_model_summerisation_t5_logit"
tokenizer = AutoTokenizer.from_pretrained(model2_path)
model2 = AutoModelForSeq2SeqLM.from_pretrained(
    model2_path,
    torch_dtype=torch.float16,
    device_map="auto"
)

# %%
prompt = "summerize the following Python is a popular high-level programming language known for its simple syntax and readability, which makes it easy for beginners to learn and powerful for professionals to use. Created by Guido van Rossum and first released in 1991, Python supports multiple programming styles, including procedural, object-oriented, and functional programming. It is widely used in many fields such as web development, data analysis, artificial intelligence, automation, and scientific computing. Frameworks and tools like Django, Flask, and libraries such as TensorFlow and NumPy make Python extremely versatile. Because of its large community, extensive libraries, and cross-platform compatibility, Python has become one of the most widely used programming languages in the world."

inputs = tokenizer(prompt, return_tensors="pt").to(model2.device)

output = model2.generate(
    **inputs,
    max_new_tokens=200,
    temperature=0.7
)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# Python is a popular high-level programming language known for its simple syntax and readability, which makes it easy for beginners to learn and powerful for professionals to use.
